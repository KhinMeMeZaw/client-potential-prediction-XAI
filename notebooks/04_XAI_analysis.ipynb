# %% [markdown]
# # 04 - XAI Analysis
# This notebook applies Explainable AI methods: SHAP, LIME, PDP, ICE.

# %%
# Step 1: Import libraries
import shap
import lime
from lime.lime_tabular import LimeTabularExplainer
import matplotlib.pyplot as plt

# %%
# Step 2: SHAP analysis
# explainer = shap.TreeExplainer(model)
# shap_values = explainer.shap_values(X_test)
# shap.summary_plot(shap_values, X_test)

# %%
# Step 3: LIME explanation
# explainer = LimeTabularExplainer(X_train.values, feature_names=X_train.columns, class_names=['No', 'Low', 'Medium', 'High'], mode='classification')
# exp = explainer.explain_instance(X_test.iloc[0], model.predict_proba)
# exp.show_in_notebook(show_table=True)

# %%
# Step 4: PDP / ICE plots (optional)
# from sklearn.inspection import plot_partial_dependence
# plot_partial_dependence(model, X_train, ['Budget in USD', 'Engagement Level'])
